# %% [markdown]
# # Setting Up GPU Memory Growth for TensorFlow

# %% [markdown]
# ## Initial setup

# %%
import tensorflow as tf
import os

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)
tf.config.list_physical_devices('GPU')

# %% [markdown]
# # Old

# %%
# Initial setup
import tensorflow as tf
import os, sys
sys.path.append(os.path.abspath("..")) # Ensure we can import src/

import src.data_loader as dl
from src.train import train_model
from importlib import reload

# %% [markdown]
# ## Load Data

# %%
reload(dl)
train_ds, val_ds = dl.get_train_val_ds()
print("Training and validation datasets loaded successfully!")
print(f"Train batches: {len(train_ds)} | Validation batches: {len(val_ds)}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[19], line 2
#       1 reload(dl)
# ----> 2 train_ds, val_ds = dl.get_train_val_ds()
#       3 print("Training and validation datasets loaded successfully!")
#       4 print(f"Train batches: {len(train_ds)} | Validation batches: {len(val_ds)}")
#
# File ~\PycharmProjects\PlantVillageMachineLearning\src\data_loader.py:9, in get_train_val_ds()
#       6 train_dir = base_dir / "train"
#       7 val_dir = base_dir / "val"
# ----> 9 train_ds = tf.keras.utils.image_dataset_from_directory(
#      10     train_dir,
#      11     image_size=config.IMG_SIZE,
#      12     batch_size=config.BATCH_SIZE,
#      13 )
#      14 val_ds = tf.keras.utils.image_dataset_from_directory(
#      15     val_dir,
#      16     image_size=config.IMG_SIZE,
#      17     batch_size=config.BATCH_SIZE,
#      18 )
#      19 return train_ds, val_ds
#
# ...

# %% [markdown]
# ## Get Class Names

# %%
class_names = train_ds.class_names
num_classes = len(class_names)
print(f"Number of classes: {num_classes}")

# %% [markdown]
# ## Train

# %%
model, history = train_model(
    train_ds,
    val_ds,
    num_classes,
    epochs=10,
    save_path="../models/plant_disease.keras"
)

print("Model saved to ../models/plant_disease.keras")

# %% [markdown]
# ## Use GPU with Memory Growth

# %%
import tensorflow as tf

gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu, True)

print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %% [markdown]
# We have enabled memory growth for the available GPUs. This helps in managing GPU memory usage more efficiently during model training.
